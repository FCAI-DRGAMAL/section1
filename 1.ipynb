# %% [markdown]
# # OpenCV with python

# %% [markdown]
# ### General import

# %%
import numpy as np
import cv2 as cv
from PIL import Image 
import cv2 as cv
import os
from skimage import io #image processing lib (image segmentation , analysis . filtering ,  face recognation)
import matplotlib.pyplot as plt

# %%
#skimage reading
img= io.imread("1.jpg")
img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img)

# %% [markdown]
# # load data

# %%
rand_img= np.random.random([500,500])

rand_img
# Out:
# array([[0.71677422, 0.79135188, 0.63058763, ..., 0.99891393, 0.10980814,
#         0.00313786],
#        [0.19778252, 0.79340447, 0.98120542, ..., 0.67096817, 0.82965079,
#         0.16710594],
#        [0.96830477, 0.70846372, 0.07034329, ..., 0.08004843, 0.08587348,
#         0.70581724],
#        ...,
#        [0.71248402, 0.75365419, 0.26402053, ..., 0.06378563, 0.11052158,
#         0.0044606 ],
#        [0.26329163, 0.4168495 , 0.76405241, ..., 0.24817542, 0.79012569,
#         0.14465212],
#        [0.53712635, 0.18635637, 0.83979428, ..., 0.18247196, 0.35110033,
#         0.28546111]])

# %%
plt.imshow(rand_img)

# %%
imgr=np.random.permutation(img)
plt.imshow(imgr)

# %% [markdown]
# # Using PIL

# %%
#read img

imgpil=Image.open("1.jpg")
type(imgpil)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# ###Convert to numpy array:

# %%
imgpil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
imgpil.format
# Out:
# 'JPEG'

# %%
imgnp= np.asarray(imgpil)
imgnp
# Out:
# array([[[129, 129, 139],
#         [129, 129, 139],
#         [130, 130, 140],
#         ...,
#         [117, 117, 117],
#         [117, 117, 117],
#         [117, 117, 117]],
#
#        [[128, 128, 138],
#         [129, 129, 139],
#         [129, 129, 139],
#         ...,
#         [116, 116, 116],
#         [116, 116, 116],
#         [116, 116, 116]],
#
#        [[127, 127, 137],
#         [128, 128, 138],
#         [128, 128, 138],
#         ...,
#         [115, 115, 115],
#         [115, 115, 115],
#         [115, 115, 115]],
#
#        ...,
#
#        [[194, 190, 179],
#         [193, 189, 178],
#         [192, 188, 177],
#         ...,
#         [ 40,  47,  57],
#         [ 40,  47,  55],
#         [ 40,  47,  55]],
#
#        [[195, 191, 180],
#         [194, 190, 179],
#         [193, 189, 178],
#         ...,
#         [ 42,  48,  60],
#         [ 42,  49,  59],
#         [ 42,  48,  60]],
#
#        [[195, 191, 180],
#         [195, 191, 180],
#         [194, 190, 179],
# ...

# %%
imge=np.random.permutation(imgnp)
plt.imshow(imge)

# %%
import matplotlib.image as plm

imgpl = plm.imread("1.jpg")
type(imgpl)
# Out:
# numpy.ndarray

# %%
imgp=np.random.permutation(imgpl)
plt.imshow(imgp)
